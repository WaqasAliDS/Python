# %%
from csv import reader

# %%
dataset = list(reader(open("AmericanGallery.csv", encoding = "utf-8")))

# %%
header = dataset[0]

# %%
header
# Out:
# ['Title',
#  'Artist',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Department']

# %%
artworks = dataset[1:]

# %%
artworks[:5]
# Out:
# [['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   '(American)',
#   '-1947',
#   '-2013',
#   '(Female)',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   '(Spanish)',
#   '-1916',
#   '-2007',
#   '(Male)',
#   '1978',
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   '(French)',
#   '-1870',
#   '-1943',
#   '(Male)',
#   '1889-1911',
#   'Prints & Illustrated Books'],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN',
#   'Aristide Maillol',
#   '(French)',
#   '-1861',
#   '-1944',
#   '(Male)',
#   '1927-1940',
#   'Prints & Illustrated Books'],
#  ['97 rue du Bac',
#   'Eugène Atget',
#   '(French)',
#   '-1857',
#   '-1927',
#   '(Male)',
#   '1903',
#   'Photography']]

# %% [markdown]
# str.replace("`Old Value`","`New Value`")

# %%
"daniyal".replace("y","")
# Out:
# 'danial'

# %%
header.index("Nationality")
# Out:
# 2

# %%
for i in artworks:
    print(i[2])
# Out:
# (American)
# (Spanish)
# (French)
# (French)
# (French)
# (American)
# (French)
# (American)
# (South African)
# (Canadian)
# (French)
# (American)
# (Czech)
# (American)
# (American)
# (American)
# (Belgian)
# (American)
# (American)
# (Spanish)
# (American)
# (Russian)
# (American)
# (French)
# (French)
# (French)
# (British)
# (French)
# (French)
# (German)
# (Belgian)
# ()
# (American)
# (American)
# (American)
# (Swiss)
# ()
# (American)
# (American)
# (Polish)
# (British)
# (American)
# (American)
# (Belgian)
# (American)
# (Japanese)
# (American)
# (American)
# (Spanish)
# (American)
# (French)
# (American)
# (American)
# (American)
# (American)
# (French)
# (American)
# (American)
# (French)
# (American)
# (American)
# (Portuguese)
# (American)
# (American)
# (Austrian)
# (Swiss)
# (German)
# (American)
# (American)
# (French)
# (British)
# (American)
# (French)
# (American)
# (British)
# (German)
# (French)
# (French)
# (Australian)
# (American)
# (French)
# (Spanish)
# ...

# %%
"(Danial)".replace("()","")
# Out:
# '(Danial)'

# %%
"(Danial)".replace("(","").replace(")","")
# Out:
# 'Danial'

# %%
for i in artworks:
    i[2] = i[2].replace("(","").replace(")","")
    print(i[2])
# Out:
# American
# Spanish
# French
# French
# French
# American
# French
# American
# South African
# Canadian
# French
# American
# Czech
# American
# American
# American
# Belgian
# American
# American
# Spanish
# American
# Russian
# American
# French
# French
# French
# British
# French
# French
# German
# Belgian
#
# American
# American
# American
# Swiss
#
# American
# American
# Polish
# British
# American
# American
# Belgian
# American
# Japanese
# American
# American
# Spanish
# American
# French
# American
# American
# American
# American
# French
# American
# American
# French
# American
# American
# Portuguese
# American
# American
# Austrian
# Swiss
# German
# American
# American
# French
# British
# American
# French
# American
# British
# German
# French
# French
# Australian
# American
# French
# Spanish
# German
# American
# American
# French
# American
# American
# American
# French
# Italian
# American
# American
# American
# American
# American
# French
# American
# ...

# %%
header.index("Gender")
# Out:
# 5

# %%
for i in artworks:
    i[5] = i[5].replace("(","").replace(")","")
    print(i[5])
# Out:
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Male
# ...

# %%
header.index("BeginDate")
# Out:
# 3

# %%
int("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10744\2022679966.py in <module>
# ----> 1 int("")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
for i in artworks:
    print(int(i[3]))
# Out:
# -1947
# -1916
# -1870
# -1861
# -1857
# -1919
# -1857
# -1928
# -1964
# -1882
# -1901
# -1935
# -1871
# -1894
# -1955
# -1878
# -1927
# -1936
# -1867
# -1932
# -1886
# -1894
# -1938
# -1926
# -1898
# -1867
# -1947
# -1868
# -1857
# -1938
# -1889
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10744\511968436.py in <module>
#       1 for i in artworks:
# ----> 2     print(int(i[3]))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
"-1999" != ""
# Out:
# True

# %%
'' != ""
# Out:
# False

# %%
for i in artworks:
    if i[3] != "":
        print(i[3])
# Out:
# -1947
# -1916
# -1870
# -1861
# -1857
# -1919
# -1857
# -1928
# -1964
# -1882
# -1901
# -1935
# -1871
# -1894
# -1955
# -1878
# -1927
# -1936
# -1867
# -1932
# -1886
# -1894
# -1938
# -1926
# -1898
# -1867
# -1947
# -1868
# -1857
# -1938
# -1889
# -1928
# -1934
# -1929
# -1930
# -1919
# -1901
# -1949
# -1753
# -1973
# -1902
# -1927
# -1867
# -1933
# -1928
# -1934
# -1893
# -1867
# -1887
# -1925
# -1938
# -1929
# -1936
# -1857
# -1948
# -1886
# -1868
# -1931
# -1911
# -1933
# -1943
# -1886
# -1870
# -1943
# -1954
# -1843
# -1898
# -1857
# -1966
# -1957
# -1903
# -1903
# -1753
# -1909
# -1857
# -1871
# -1927
# -1890
# -1883
# -1927
# -1945
# -1954
# -1947
# -1864
# -1904
# -1948
# -1931
# -1871
# -1955
# -1890
# -1934
# -1915
# -1886
# -1931
# -1857
# -1886
# -1857
# -1958
# -1934
# -1867
# -1877
# -1978
# -1963
# -1922
# -1831
# -1947
# -1857
# -1967
# -1893
# -1905
# -1830
# -1924
# -1934
# -1881
# -1910
# -1886
# -1936
# -1901
# -1911
# -1890
# -1943
# -1871
# -1911
# -1946
# -1954
# ...

# %%
for i in artworks:
    if i[3] != "":
        i[3] = int(i[3].replace("-",""))
    print(i[3])
# Out:
# 1947
# 1916
# 1870
# 1861
# 1857
# 1919
# 1857
# 1928
# 1964
# 1882
# 1901
# 1935
# 1871
# 1894
# 1955
# 1878
# 1927
# 1936
# 1867
# 1932
# 1886
# 1894
# 1938
# 1926
# 1898
# 1867
# 1947
# 1868
# 1857
# 1938
# 1889
#
# 1928
# 1934
# 1929
# 1930
#
# 1919
# 1901
# 1949
# 1753
# 1973
# 1902
# 1927
# 1867
# 1933
# 1928
# 1934
# 1893
# 1867
# 1887
# 1925
# 1938
# 1929
# 1936
# 1857
# 1948
# 1886
# 1868
# 1931
# 1911
# 1933
# 1943
# 1886
# 1870
# 1943
# 1954
# 1843
# 1898
# 1857
# 1966
# 1957
# 1903
# 1903
# 1753
# 1909
# 1857
# 1871
# 1927
# 1890
# 1883
# 1927
# 1945
# 1954
# 1947
# 1864
# 1904
# 1948
# 1931
# 1871
# 1955
# 1890
# 1934
# 1915
# 1886
# 1931
# 1857
# 1886
# 1857
# 1958
# 1934
# 1867
# 1877
# 1978
# 1963
# 1922
# 1831
# 1947
# 1857
#
# 1967
# 1893
# 1905
# 1830
# 1924
# 1934
# 1881
# 1910
# 1886
# 1936
# 1901
# 1911
# 1890
# 1943
# 1871
# 1911
# 1946
# 1954
# 1938
# 1871
# 1885
# 1917
# 1868
# 1923
# 1909
# 1870
# 1900
# 2005
# 1884
# 1947
# 1913
# 1903
# 1880
# 1874
# 1941
# ...

# %%
for i in artworks:
    if i[4] != "":
        i[4] = int(i[4].replace("-",""))
    print(i[4])
# Out:
# 2013
# 2007
# 1943
# 1944
# 1927
# 2013
# 1927
# 1984
#
# 1953
# 1985
#
# 1957
# 1972
#
# 1965
#
#
# 1959
#
# 1969
# 1958
#
# 1987
# 1976
# 1947
#
# 1941
# 1927
#
# 1972
#
# 2007
# 2006
#
# 1998
#
# 2013
# 1978
#
# 1828
#
# 1988
#
# 1959
#
# 1987
#
# 1983
# 1959
# 1985
# 2008
# 2011
#
#
# 1927
#
# 1969
# 1941
# 1978
# 2010
#
#
# 1969
# 1956
#
#
# 1908
# 1957
# 1927
#
# 1996
# 1976
# 1991
# 1828
# 1981
# 1927
# 1958
# 1982
# 1976
# 1956
#
# 2014
#
#
# 1901
# 1997
#
# 2006
# 1958
#
# 1965
#
# 2004
# 1969
# 1978
# 1927
# 1969
# 1927
#
# 2016
# 1959
# 1960
#
#
# 2000
# 1913
#
# 1927
#
#
# 1983
# 1970
# 1904
#
#
# 1955
# 2007
# 1969
#
# 1985
# 2010
# 1976
#
# 1951
# 2010
#
#
#
# 1957
# 1947
# 1992
# 1933
# 2012
# 2002
# 1943
# 1985
#
# 1974
#
# 1989
# 1962
# 1938
# 1948
#
# 1952
# 2003
# 1978
#
#
#
# 1976
# 2016
#
#
# 1930
# 1988
# 2002
# 2013
# 2013
# 1928
# 1985
# 2012
# 1944
# 1934
# 1966
# 2010
# 1904
# 1927
# 1969
# 2008
# 1979
#
#
#
# 1987
# 1988
#
#
# 1985
# 1991
# 1969
# 2010
# ...

# %%
bad_char = ["(",")","s","S","c","C",".","'"," "]

# %%
value = "(c. 1999-2020's)"

# %%
for i in bad_char:
    value = value.replace(i, "")

print(value)
# Out:
# 1999-2020

# %%
for i in artworks: 
    print(i[-2]) # i[-2] = 1978
    for j in bad_char: # j = "'"
        i[-2] = i[-2].replace(j,"")
    
    print(i[-2])
# Out:
# 1986
# 1986
# 1978
# 1978
# 1889-1911
# 1889-1911
# 1927-1940
# 1927-1940
# 1903
# 1903
# 1957
# 1957
# 1924
# 1924
# 1978-1983
# 1978-1983
# 2001
# 2001
# -1941
# -1941
# 1949-1950
# 1949-1950
# 1963
# 1963
# 1908-1911
# 1908-1911
# -1934
# -1934
# 1997
# 1997
# (1931-1933)
# 1931-1933
# 1972
# 1972
# 1967
# 1967
# 1923-1924
# 1923-1924
# 1979
# 1979
# 1925-1927
# 1925-1927
# 1929
# 1929
# 1972
# 1972
# 1974
# 1974
# 1957
# 1957
# 1920-1930
# 1920-1930
# 1974
# 1974
# 1915
# 1915
# 1912
# 1912
# 1988-1990
# 1988-1990
# 1925
# 1925
# c. 1925
# 1925
# 1980
# 1980
# 1964
# 1964
# 1968
# 1968
# 1969
# 1969
# 1934
# 1934
# 1953
# 1953
# 1971
# 1971
# 1988
# 1988
# 1818
# 1818
# 2002
# 2002
# 1926
# 1926
# 1969
# 1969
# 1914
# 1914
# 1979
# 1979
# 1968
# 1968
# 1979
# 1979
# 1966
# 1966
# 1904
# 1904
# 1949
# 1949
# 1981
# 1981
# 1970
# 1970
# 1969
# 1969
# 1972
# 1972
# 1923-1925
# 1923-1925
# 1967
# 1967
# 1932
# 1932
# 1928
# 1928
# 1965
# 1965
# 2003
# 2003
# 1971-1974
# 1971-1974
# ...

# %%
for i in artworks:
    if "(" in i[-2]:
        print(i[-2])

# %%
"-1999"[0] == "-"
# Out:
# True

# %%
"1999-1000"[0] == "-"
# Out:
# False

# %%
"-1000".startswith("-")
# Out:
# True

# %%
for i in artworks:
    if i[-2].startswith("-"):
        print(i[-2])
# Out:
# -1941
# -1934
# -2003
# -1926
# -1916
# -1919
# -1965
# -1966
# -1926
# -1970
# -1911
# -1952
# -1960
# -1966
# -1989
# -1923
# -2004
# -2003
# -2003
# -1993
# -1987
# -1951
# -2002
# -1992
# -2000
# -1961
# -1972
# -1974
# -1937
# -1949
# -1942
# -1967
# -1950
# -1934
# -1976
# -2001
# -1916
# -1913
# -1972
# -1983
# -1978
# -1908
# -1927
# -1924
# -1970
# -1931
# -1996
# -1974
# -1955
# -1970
# -1987
# -1963
# -1973
# -1966
# -1966
# -2001
# -1918
# -1942
# -1913
# -1977
# -1945
# -1961
# -1966
# -1918
# -1967
# -1946
# -1940
# -1906
# -1927
# -1955
# -1969
# -1972
# -1908
# -1954
# -1916
# -1978
# -1970
# -1984
# -1961
# -2003
# -2007
# -1913
# -1984
# -1990
# -1966
# -1940
# -2003
# -1966
# -1942
# -1973
# -2000
# -1972
# -1947
# -1965
# -1956
# -1961
# -1974
# -1966
# -1968
# -1911
# -2003
# -1913
# -2003
# -1964
# -1913
# -1973
# -1913
# -1993
# -1924
# -1991
# -1966
# -1974
# -1916
# -1963
# -1921
# -1960
# -1939
# -1960
# -1964
# -1956
# -1957
# -1965
# -1913
# -1965
# -2004
# ...

# %%
for i in artworks:
    if i[-2].startswith("-"):
        i[-2] = i[-2].replace("-","")
    print(i[-2])
# Out:
# 1986
# 1978
# 1889-1911
# 1927-1940
# 1903
# 1957
# 1924
# 1978-1983
# 2001
# 1941
# 1949-1950
# 1963
# 1908-1911
# 1934
# 1997
# 1931-1933
# 1972
# 1967
# 1923-1924
# 1979
# 1925-1927
# 1929
# 1972
# 1974
# 1957
# 1920-1930
# 1974
# 1915
# 1912
# 1988-1990
# 1925
# 1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 1923-1925
# 1967
# 1932
# 1928
# 1965
# 2003
# 1971-1974
# 1983
# 1930
# 1946
# 1984
# 2006
# 1885
# 1942
# 1913
# 2015
# 1987
# 1947-1949
# 1965
# 1818
# 1961
# 1925
# 1916-1932
# 1962
# 1944
# 1930
# 1991
# 1991-1994
# 2008
# 1975
# 1893
# 1966
# 1968-1969
# 1964-1968
# 1928-1939
# 1969
# 1942
# 1980
# 1955
# 1930
# 1955-1960
# 1922
# 1934
# 1903
# 2008
# 1962
# 1944
# 1914-1918
# 2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# 1986
# ...

# %%
"1930-50"
# Out:
# '1930-50'

# %%
"-" in "1930-50"
# Out:
# True

# %%
for i in artworks:
    if "-" in i[-2]:
        print(i[-2])
# Out:
# 1889-1911
# 1927-1940
# 1978-1983
# 1949-1950
# 1908-1911
# 1931-1933
# 1923-1924
# 1925-1927
# 1920-1930
# 1988-1990
# 1923-1925
# 1971-1974
# 1947-1949
# 1916-1932
# 1991-1994
# 1968-1969
# 1964-1968
# 1928-1939
# 1955-1960
# 1914-1918
# 1908-1911
# 1933-1947
# 1968-1977
# 1919-1920
# 1923-1948
# 1912-1926
# 1926-1946
# 1991-1994
# 1936-1937
# 1978-1979
# 1919-1920
# 1965-1966
# 1923-1951
# 1916-1932
# 1900-1910
# 1931-1956
# 1899-1900
# 1920-1930
# 1985-1986
# 1872-1927
# 1923-1924
# 1913-1921
# 1826-1896
# 1926-1938
# 1962-1963
# 1970-1971
# 1959-1965
# 1949-1950
# 1921-1922
# 1947-1955
# 1953-1954
# 1943-1981
# 1931-1956
# 1971-1973
# 1955-1956
# 1899-1900
# 1911-1950
# 1946-1949
# 1908-1911
# 1946-1947
# 1970-1972
# 1925-1927
# 1971-1974
# 1900-1953
# 2008-2010
# 1943-1981
# 1925-1927
# 1989-1990
# 1999-2001
# 1962-1965
# 1930-1931
# 1979-1984
# 1938-1960
# 1923-1948
# 1998-2003
# 1977-1978
# 1997-2000
# 1928-1939
# 1908-1950
# 1926-1938
# 1906-1912
# 1975-1976
# 1900-1943
# ...

# %%
len("1925-27")
# Out:
# 7

# %%
for i in artworks:
    if "-" in i[-2] and len(i[-2]) != 9:
        print(i[-2])
# Out:
# 1910-30
# 1910-30
# 1880-90
# 1910-30

# %%
value = "1910-30"

# %%
value[:5]
# Out:
# '1910-'

# %%
value[:2]
# Out:
# '19'

# %%
value[5:]
# Out:
# '30'

# %%
value[:5] + value[:2] + value[5:]
# Out:
# '1910-1930'

# %%
for i in artworks:
    if "-" in i[-2] and len(i[-2]) != 9:
        value = i[-2]
        value = value[:5] + value[:2] + value[5:]
        i[-2] = value

# %%
for i in artworks:
    if "-" in i[-2] and len(i[-2]) != 9:
        print(i[-2])

# %%
"1910-1930".split("-")
# Out:
# ['1910', '1930']

# %%
(12, 34)
# Out:
# (12, 34)

# %%
year = "1910-1930"
year = "1910-1930".split("-")
year
# Out:
# ['1910', '1930']

# %%
first = int(year[0])
second = int(year[1])

# %%
avg = round((first + second) / len(year))
avg
# Out:
# 1920

# %%
for i in artworks:
    year = i[-2]
    if "-" in year:
        year = year.split("-")
        first = int(year[0])
        second = int(year[1])
        avg = round((first + second) / len(year))
        i[-2] = avg
    print(i[-2])
# Out:
# 1986
# 1978
# 1900
# 1934
# 1903
# 1957
# 1924
# 1980
# 2001
# 1941
# 1950
# 1963
# 1910
# 1934
# 1997
# 1932
# 1972
# 1967
# 1924
# 1979
# 1926
# 1929
# 1972
# 1974
# 1957
# 1925
# 1974
# 1915
# 1912
# 1989
# 1925
# 1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 1924
# 1967
# 1932
# 1928
# 1965
# 2003
# 1972
# 1983
# 1930
# 1946
# 1984
# 2006
# 1885
# 1942
# 1913
# 2015
# 1987
# 1948
# 1965
# 1818
# 1961
# 1925
# 1924
# 1962
# 1944
# 1930
# 1991
# 1992
# 2008
# 1975
# 1893
# 1966
# 1968
# 1966
# 1934
# 1969
# 1942
# 1980
# 1955
# 1930
# 1958
# 1922
# 1934
# 1903
# 2008
# 1962
# 1944
# 1916
# 2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# 1986
# 1982
# 1910
# 1934
# 1971
# 1926
# 1960
# 1939
# 1893
# 1952
# 2007
# 1940
# 1995
# 1973
# 1939
# ...

# %%
for i in artworks:
    i[-2] = int(i[-2])
